# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('/content/data_science_job.csv')

# %%
df.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.shape
# Out:
# (19158, 13)

# %%
cols=[var for var in df.columns if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
len(df[cols].dropna())/len(df) #percentage of remaining data is the output
# Out:
# 0.8968577095730244

# %%
new_df=df[cols].dropna()

# %%
df.shape,new_df.shape
# Out:
# ((19158, 13), (17182, 5))

# %%
new_df.hist(bins=50,density=True,figsize=(12,12))
plt.show()

# %%
df1=pd.read_csv('/content/titanic_toy.csv')

# %%
df1.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df1.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
X = df1.drop(columns = ['Survived'])
y=df1['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2) # Splitting the dataset

mean_age = x_train['Age'].mean() # Calculate mean of age using the correctly named variable x_train
median_age = x_train['Age'].median()

mean_fare = x_train['Fare'].mean()
median_fare = x_train['Fare'].median()

# %%
x_train['Age_median'] = x_train['Age'].fillna(99) # Use lowercase x_train
x_train['Fare_median'] = x_train['Fare'].fillna(-1)

x_train['Age_mean'] = x_train['Age'].fillna(999) # Use lowercase x_test
x_train['Fare_mean'] = x_train['Fare'].fillna(-1)

# %%
x_train.sample(5)
# Out:
#       Age      Fare  Family  Age_median  Fare_median  Age_mean  Fare_mean
# 45    NaN    8.0500       0        99.0       8.0500     999.0     8.0500
# 66   29.0   10.5000       0        29.0      10.5000      29.0    10.5000
# 718   NaN   15.5000       0        99.0      15.5000     999.0    15.5000
# 31    NaN  146.5208       1        99.0     146.5208     999.0   146.5208
# 54   65.0   61.9792       1        65.0      61.9792      65.0    61.9792

# %%
print(x_train['Age'].var())
print(x_train['Age_median'].var())
print(x_train['Age_mean'].var())

print(x_train['Fare'].var())
print(x_train['Fare_median'].var())
print(x_train['Fare_mean'].var())
# Out:
# 204.34951339046142
# 951.7275570187188
# 155054.41209691347
# 2448.1979137063163
# 2378.5676784883494
# 2378.5676784883494

# %%
x_train.cov()
# Out:
#                     Age         Fare     Family    Age_median  Fare_median  \
# Age          204.349513    70.719262  -6.498901    204.349513    63.321188
# Fare          70.719262  2448.197914  17.258917   -101.671097  2448.197914
# Family        -6.498901    17.258917   2.735252     -7.387287    16.553989
# Age_median   204.349513  -101.671097  -7.387287    951.727557   -94.317400
# Fare_median   63.321188  2448.197914  16.553989    -94.317400  2378.567678
# Age_mean     204.349513 -2146.736242 -36.529656  11223.095428 -1972.721263
# Fare_mean     63.321188  2448.197914  16.553989    -94.317400  2378.567678
#
#                   Age_mean    Fare_mean
# Age             204.349513    63.321188
# Fare          -2146.736242  2448.197914
# Family          -36.529656    16.553989
# Age_median    11223.095428   -94.317400
# Fare_median   -1972.721263  2378.567678
# Age_mean     155054.412097 -1972.721263
# Fare_mean     -1972.721263  2378.567678
# ...

# %%
x_train[['Age','Age_median','Age_mean']].boxplot()
# Out:
# <Axes: >

# %%
x_train[['Fare','Fare_median','Fare_mean']].boxplot()
# Out:
# <Axes: >
